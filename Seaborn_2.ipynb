# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Waleed-Source/Chat-Room/blob/main/Seaborn_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

# %% [markdown]
# ## 4. Categorical Plots
#
# ### Categorical Scatter Plot
#
# - Stripplot
# - Swarmplot
#
# ### Categorical Distribution Plots
#
# - Boxplot
# - Violinplot
#
# ### Categorical Estimate Plot -> for central tendency
#
# - Barplot
# - Pointplot
# - Countplot
#
# ### Figure level function -> `catplot`

# %% [markdown]
# ## 4.1 Categorical Scatter Plot

# %% [markdown]
# ### 4.1.1 Strip Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# axes level function

sns.stripplot(data=tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# if we want the scatter in a line
sns.stripplot(data=tips, x='day', y='total_bill', jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# figure level function using catplot

sns.catplot(tips, x='day', y='total_bill', kind='strip', hue='sex')

# %%
# jitter
sns.catplot(tips, x='day', y='total_bill', kind='strip', jitter=0.3)

# %% [markdown]
# ### 4.1.2 Swarm Plot

# %%
# represent distribution a bit

# axes level function
sns.swarmplot(tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# figure level function

sns.catplot(tips, x='day', y='total_bill', kind='swarm')

# %%
# hue
sns.catplot(tips, x='day', y='total_bill', kind='swarm', hue='sex')
